# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


#disabling warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Loading data from CSV
churn = pd.read_csv("C:/Users/tyson/Documents/GitHub/WGU_MSDA_Portfolio/Predictive Modeling – D208/R/Raw/churn_clean.csv")

# %%
# Summary of the data
print(churn.describe())  # Summary statistics for numerical columns
print(churn.info())  # Quick overview of data types and non-null counts
# Out:
#          CaseOrder           Zip           Lat           Lng     Population  \
# count  10000.00000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    5000.50000  49153.319600     38.757567    -90.782536    9756.562400
# std     2886.89568  27532.196108      5.437389     15.156142   14432.698671
# min        1.00000    601.000000     17.966120   -171.688150       0.000000
# 25%     2500.75000  26292.500000     35.341828    -97.082812     738.000000
# 50%     5000.50000  48869.500000     39.395800    -87.918800    2910.500000
# 75%     7500.25000  71866.500000     42.106908    -80.088745   13168.000000
# max    10000.00000  99929.000000     70.640660    -65.667850  111850.000000
#
#          Children           Age         Income  Outage_sec_perweek  \
# count  10000.0000  10000.000000   10000.000000        10000.000000
# mean       2.0877     53.078400   39806.926771           10.001848
# std        2.1472     20.698882   28199.916702            2.976019
# ...

# %%
# Checking for duplicates
duplicate_count = churn.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
# Checking for missing values
missing_values = churn.isna().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  CaseOrder                  0
# Customer_id                0
# Interaction                0
# UID                        0
# City                       0
# State                      0
# County                     0
# Zip                        0
# Lat                        0
# Lng                        0
# Population                 0
# Area                       0
# TimeZone                   0
# Job                        0
# Children                   0
# Age                        0
# Income                     0
# Marital                    0
# Gender                     0
# Churn                      0
# Outage_sec_perweek         0
# Email                      0
# Contacts                   0
# Yearly_equip_failure       0
# Techie                     0
# Contract                   0
# Port_modem                 0
# Tablet                     0
# InternetService         2129
# Phone                      0
# Multiple                   0
# ...

# %%
# python seems to be treating 'None' as nan. 
print(churn.InternetService.unique())

churn['InternetService'].isna().sum()
# Out:
# ['Fiber Optic' 'DSL' nan]
# 2129

# %%
# updating nan to be 'None' to match the data dictionary
churn['InternetService'].fillna('None', inplace=True)

# %%
churn['InternetService'].isna().sum()  # Check how many missing values there are
# Out:
# 0

# %%
print(churn.InternetService.unique())
missing_values = churn.isna().sum()
print("Missing values per column:\n", missing_values)
# Out:
# ['Fiber Optic' 'DSL' 'None']
# Missing values per column:
#  CaseOrder               0
# Customer_id             0
# Interaction             0
# UID                     0
# City                    0
# State                   0
# County                  0
# Zip                     0
# Lat                     0
# Lng                     0
# Population              0
# Area                    0
# TimeZone                0
# Job                     0
# Children                0
# Age                     0
# Income                  0
# Marital                 0
# Gender                  0
# Churn                   0
# Outage_sec_perweek      0
# Email                   0
# Contacts                0
# Yearly_equip_failure    0
# Techie                  0
# Contract                0
# Port_modem              0
# Tablet                  0
# InternetService         0
# Phone                   0
# Multiple                0
# OnlineSecurity          0
# OnlineBackup            0
# ...

# %% [markdown]
# # Handling Outliers

# %% [markdown]
# ### Population

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(churn['Population'])
plt.title('Boxplot of Population')
plt.xlabel('Population')
plt.show()

# %%
# Summary statistics
Q1 = churn['Population'].quantile(0.25)
Q3 = churn['Population'].quantile(0.75)

# Interquartile Range (IQR)
IQR = Q3 - Q1

# outliers
outlier_threshold_upper = Q3 + 1.5 * IQR
outlier_threshold_lower = Q1 - 1.5 * IQR

print("Outliers begin above:", outlier_threshold_upper)
# Out:
# Outliers begin above: 31813.0

# %%
# Population
churn['Population'] = np.where(churn['Population'] > 31813, churn['Population'], churn['Population']) # Retaining outliers

# %% [markdown]
# ### Email

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(churn['Email'].dropna())
plt.title('Boxplot of Email')
plt.xlabel('Email')
plt.show()

# %%
# Summary statistics
Q1 = churn['Email'].quantile(0.25)
Q3 = churn['Email'].quantile(0.75)

# Interquartile Range (IQR)
IQR = Q3 - Q1

# outliers
outlier_threshold_upper = Q3 + 1.5 * IQR
outlier_threshold_lower = Q1 - 1.5 * IQR

print("Outliers begin above:", outlier_threshold_upper)
print("Outliers begin below:", outlier_threshold_lower)
# Out:
# Outliers begin above: 20.0
# Outliers begin below: 4.0

# %%
# Email
churn['Email'] = np.where((churn['Email'] < 4) | (churn['Email'] > 20), np.nan, churn['Email'])
churn['Email'].fillna(churn['Email'].mean(), inplace=True)

# %% [markdown]
# ### Yearly_equip_failure

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(churn['Yearly_equip_failure'])
plt.title('Boxplot of Yearly Equipment Failures')
plt.xlabel('Yearly Equipment Failures')
plt.show()

# %%
# Summary statistics
Q1 = churn['Yearly_equip_failure'].quantile(0.25)
Q3 = churn['Yearly_equip_failure'].quantile(0.75)

# Interquartile Range (IQR)
IQR = Q3 - Q1

# outliers
outlier_threshold_upper = Q3 + 1.5 * IQR
outlier_threshold_lower = Q1 - 1.5 * IQR

print("Outliers begin above:", outlier_threshold_upper)
print("Outliers begin below:", outlier_threshold_lower)
# Out:
# Outliers begin above: 2.5
# Outliers begin below: -1.5

# %%
# Yearly_equip_failure
churn['Yearly_equip_failure'] = np.where(churn['Yearly_equip_failure'] > 2.5, np.nan, churn['Yearly_equip_failure'])
churn['Yearly_equip_failure'].fillna(churn['Yearly_equip_failure'].median(), inplace=True)

# %% [markdown]
# ### Contacts

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(churn['Contacts'])
plt.title('Boxplot of Yearly Equipment Contacts')
plt.xlabel('Yearly Equipment Failures')
plt.show()

# %%
# Summary statistics
Q1 = churn['Contacts'].quantile(0.25)
Q3 = churn['Contacts'].quantile(0.75)

# Interquartile Range (IQR)
IQR = Q3 - Q1

# outliers
outlier_threshold_upper = Q3 + 1.5 * IQR
outlier_threshold_lower = Q1 - 1.5 * IQR

print("Outliers begin above:", outlier_threshold_upper)
# Out:
# Outliers begin above: 5.0

# %%
# Contacts
churn['Contacts'] = np.where(churn['Contacts'] > 5, np.nan, churn['Contacts'])
churn['Contacts'].fillna(churn['Contacts'].median(), inplace=True)

# %% [markdown]
# ### Children

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(churn['Children'])
plt.title('Boxplot of Children')
plt.xlabel('Children')
plt.show()

# %%
# Summary statistics
Q1 = churn['Children'].quantile(0.25)
Q3 = churn['Children'].quantile(0.75)

# Interquartile Range (IQR)
IQR = Q3 - Q1

# outliers
outlier_threshold_upper = Q3 + 1.5 * IQR
outlier_threshold_lower = Q1 - 1.5 * IQR

print("Outliers begin above:", outlier_threshold_upper)
# Out:
# Outliers begin above: 7.5

# %%
# Children
churn['Children'] = np.where(churn['Children'] > 7.5, np.nan, churn['Children'])
churn['Children'].fillna(churn['Children'].median(), inplace=True)

# %% [markdown]
# ### Income

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(churn['Income'])
plt.title('Boxplot of Income')
plt.xlabel('Income')
plt.show()

# %%
# Summary statistics
Q1 = churn['Income'].quantile(0.25)
Q3 = churn['Income'].quantile(0.75)

# Interquartile Range (IQR)
IQR = Q3 - Q1

# outliers
outlier_threshold_upper = Q3 + 1.5 * IQR
outlier_threshold_lower = Q1 - 1.5 * IQR

print("Outliers begin above:", outlier_threshold_upper)
# Out:
# Outliers begin above: 104278.34875

# %%
# Income
churn['Income'] = np.where(churn['Income'] > 104278, churn['Income'], churn['Income']) # Retaining outliers

# %% [markdown]
# ### Other Data Quality Issues

# %%
# Removing white space and ensuring that all Zips are 5 digets
churn['Zip'] = churn['Zip'].astype(str).str.zfill(5).str.strip()

# %%
# making Gender match data dictionary
churn['Gender'] = churn['Gender'].replace({"Prefer not to answer": "Nonbinary"}).astype('category')
print(churn.Gender.unique())
# Out:
# ['Male', 'Female', 'Nonbinary']
# Categories (3, object): ['Female', 'Male', 'Nonbinary']

# %%
# converting columns to categorical
categorical_columns = ['Contract', 'InternetService', 'Area', 'Marital', 'State', 'PaymentMethod']
churn[categorical_columns] = churn[categorical_columns].astype('category')

# %%
# Converting columns to Numeric
numeric_columns = ['Tenure', 'MonthlyCharge', 'Bandwidth_GB_Year', 'Outage_sec_perweek']
churn[numeric_columns] = churn[numeric_columns].apply(pd.to_numeric)

# %%
# Converting to Boolean Data Type
bool_columns = [
    'Churn', 'Techie', 'Port_modem', 'Tablet', 'Phone', 'Multiple',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies', 'PaperlessBilling'
]

# %%
for col in bool_columns:
    churn[col] = churn[col].str.strip().apply(lambda x: True if x == 'Yes' else False)

# %%
# Updating Payment Method to Match Data Dictionary
churn['PaymentMethod'] = churn['PaymentMethod'].str.lower()
churn['PaymentMethod'] = churn['PaymentMethod'].replace({
    "bank transfer(automatic)": "bank (automatic bank transfer)"
})
churn['PaymentMethod'] = churn['PaymentMethod'].astype('category')

# %%
# Rounding Numeric Columns
churn['Tenure'] = churn['Tenure'].round(2)
churn['MonthlyCharge'] = churn['MonthlyCharge'].round(2)
churn['Bandwidth_GB_Year'] = churn['Bandwidth_GB_Year'].round(0)
churn['Income'] = churn['Income'].round(2)
churn['Outage_sec_perweek'] = churn['Outage_sec_perweek'].round(0)

# %%
# Renaming Survey Response Columns
churn = churn.rename(columns={
    churn.columns[42]: "Timely_response",
    churn.columns[43]: "Timely_fixes",
    churn.columns[44]: "Timely_replacements",
    churn.columns[45]: "Reliability",
    churn.columns[46]: "Options",
    churn.columns[47]: "Respectful",
    churn.columns[48]: "Courteous",
    churn.columns[49]: "Active_listening"
})
print(churn.columns)
# Out:
# Index(['CaseOrder', 'Customer_id', 'Interaction', 'UID', 'City', 'State',
#        'County', 'Zip', 'Lat', 'Lng', 'Population', 'Area', 'TimeZone', 'Job',
#        'Children', 'Age', 'Income', 'Marital', 'Gender', 'Churn',
#        'Outage_sec_perweek', 'Email', 'Contacts', 'Yearly_equip_failure',
#        'Techie', 'Contract', 'Port_modem', 'Tablet', 'InternetService',
#        'Phone', 'Multiple', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'PaymentMethod', 'Tenure', 'MonthlyCharge',
#        'Bandwidth_GB_Year', 'Timely_response', 'Timely_fixes',
#        'Timely_replacements', 'Reliability', 'Options', 'Respectful',
#        'Courteous', 'Active_listening'],
#       dtype='object')

# %%
# Rename columns to consistent naming conventions
churn = churn.rename(columns={
    'InternetService': 'Internet_service',
    'OnlineSecurity': 'Online_security',
    'TechSupport': 'Tech_support',
    'PaperlessBilling': 'Paperless_billing',
    'CaseOrder': 'Index',
    'OnlineBackup': 'Online_backup',
    'StreamingTV': 'Streaming_TV',
    'PaymentMethod': 'Payment_method',
    'Customer_id': 'Customer_ID',
    'DeviceProtection': 'Device_protection',
    'StreamingMovies': 'Streaming_movies',
    'MonthlyCharge': 'Monthly_charge',
    'Bandwidth_GB_Year': 'Bandwidth_GB_year',
    'Outage_sec_perweek': 'Outage_sec_per_week'
})

# %%
# Checking the final modifications
churn.head()
# Out:
#    Index Customer_ID                           Interaction  \
# 0      1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1      2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2      3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3      4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4      5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
#
#                                 UID         City State                 County  \
# 0  e885b299883d4f9fb18e39c75155d990  Point Baker    AK  Prince of Wales-Hyder
# 1  f2de8bef964785f41a2959829830fb8a  West Branch    MI                 Ogemaw
# 2  f1784cfa9f6d92ae816197eb175d3c71      Yamhill    OR                Yamhill
# 3  dc8a365077241bb5cd5ccd305136b05e      Del Mar    CA              San Diego
# 4  aabb64a116e83fdc4befc1fbab1663f9    Needville    TX              Fort Bend
#
#      Zip       Lat        Lng  ...  Monthly_charge Bandwidth_GB_year  \
# ...

# %%
print(churn.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Index                 10000 non-null  int64
#  1   Customer_ID           10000 non-null  object
#  2   Interaction           10000 non-null  object
#  3   UID                   10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  category
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  object
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  category
#  12  TimeZone              10000 non-null  object
#  13  Job                   10000 non-null  object
# ...

# %%
import statsmodels.api as sm

# Define the independent variable (Bandwidth_GB_year) and dependent variable (Monthly_charge)
X = churn['Bandwidth_GB_year']
y = churn['Monthly_charge']

# Add a constant (intercept) to the independent variable
X = sm.add_constant(X)

# Create the model
model = sm.OLS(y, X)

# Fit the model and get the summary
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Monthly_charge   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     36.62
# Date:                Sun, 10 Nov 2024   Prob (F-statistic):           1.49e-09
# Time:                        10:31:22   Log-Likelihood:                -51769.
# No. Observations:               10000   AIC:                         1.035e+05
# Df Residuals:                    9998   BIC:                         1.036e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               168.5977      0.792    212.987      0.000     167.046     170.149
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatter plot with a regression line
sns.lmplot(x='Bandwidth_GB_year', y='Monthly_charge', data=churn, hue='Churn', aspect=1.5, height=6, logistic=False)

# Set plot title and labels
plt.title('Monthly Charge vs Bandwidth_GB_year with Regression Line')
plt.xlabel('Bandwidth_GB_year')
plt.ylabel('Monthly Charge')

# Show the plot
plt.show()

# %%
# List of explainer variables (independent variables)
explainer_vars = ['Tenure', 'Income', 'Children', 'Age', 'Population', 'Contacts', 
                  'Yearly_equip_failure', 'Outage_sec_per_week', 'Email', 'Monthly_charge']

# Select the independent variables
X = churn[explainer_vars]  

# The dependent variable (MonthlyCharge)
y = churn['Monthly_charge']

# Add a constant (intercept) to the independent variables
X = sm.add_constant(X)

# Create the OLS model
model = sm.OLS(y, X)

# Fit the model
results = model.fit()

# Print the summary of the regression model
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Monthly_charge   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.166e+27
# Date:                Sun, 10 Nov 2024   Prob (F-statistic):               0.00
# Time:                        10:32:45   Log-Likelihood:             2.2530e+05
# No. Observations:               10000   AIC:                        -4.506e+05
# Df Residuals:                    9989   BIC:                        -4.505e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  -5.4e-13   3.02e-12     -0.179      0.858   -6.45e-12    5.37e-12
# ...
